# %%
print("Day 1: AIML Internship - Environment Setup Complete")
print("Installed: Python, VS Code, Jupyter Notebook, Git")
print("Ready to start the AIML journey with Codomax Digital Solutions!")
# Out:
# Day 1: AIML Internship - Environment Setup Complete
# Installed: Python, VS Code, Jupyter Notebook, Git
# Ready to start the AIML journey with Codomax Digital Solutions!
